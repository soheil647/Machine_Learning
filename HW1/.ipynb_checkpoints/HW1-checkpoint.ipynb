# %% [markdown]
# # Question 6

# %%
import numpy as np
import pandas as pd
import seaborn as sn
from skimage import io
import os

# %%
def load_images_from_folder(folder):
    images = []
    average_colors = []
    labels = []
    for filename in os.listdir(folder):
        if filename[0] == 'm':
            labels.append('red')
        else:
            labels.append('blue')
        img = io.imread(os.path.join(folder,filename))
        if img is not None:
            images.append(img)
            average = img.mean(axis=0).mean(axis=0)
            average_colors.append(average)
    return images, labels, average_colors

images, labels, averages = load_images_from_folder('images')

# %%
plt.imshow(images[71])
print(averages[71])
print(labels[71])
# Out:
# [127.27044213 109.19372081  90.62028813]
# red

# %%
from collections import Counter

target_names = ['red', 'blue']
train = images
targets = labels
predict_targets = ['red' if average[0] > average[1] else 'blue' for average in averages]

print(len(train), len(target), len(predict_targets))
print(Counter(targets).keys(), Counter(targets).values())
print(Counter(predict_targets).keys(), Counter(predict_targets).values())
# Out:
# 122 122 122
# dict_keys(['blue', 'red']) dict_values([64, 58])
# dict_keys(['blue', 'red']) dict_values([39, 83])

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(targets, predict_targets, target_names=target_names))
matrix = confusion_matrix(targets, predict_targets)

df_cm = pd.DataFrame(matrix, index = ['blue', 'red'], columns = ['blue', 'red'])
plt.figure(figsize = (4,4))
sn.heatmap(df_cm, annot=True)

for i in range(len(predict_targets)):
    print('Image number : ', i, ' True Label :', targets[i], ' Predicted Label : ', predict_targets[i])
# Out:
#               precision    recall  f1-score   support
#
#          red       0.92      0.56      0.70        64
#         blue       0.66      0.95      0.78        58
#
#     accuracy                           0.75       122
#    macro avg       0.79      0.76      0.74       122
# weighted avg       0.80      0.75      0.74       122
#
# Image number :  0  True Label : blue  Predicted Label :  blue
# Image number :  1  True Label : blue  Predicted Label :  blue
# Image number :  2  True Label : blue  Predicted Label :  red
# Image number :  3  True Label : blue  Predicted Label :  blue
# Image number :  4  True Label : blue  Predicted Label :  blue
# Image number :  5  True Label : blue  Predicted Label :  blue
# Image number :  6  True Label : blue  Predicted Label :  red
# Image number :  7  True Label : blue  Predicted Label :  blue
# Image number :  8  True Label : blue  Predicted Label :  red
# Image number :  9  True Label : blue  Predicted Label :  blue
# Image number :  10  True Label : blue  Predicted Label :  red
# Image number :  11  True Label : blue  Predicted Label :  red
# Image number :  12  True Label : blue  Predicted Label :  blue
# Image number :  13  True Label : blue  Predicted Label :  red
# Image number :  14  True Label : blue  Predicted Label :  blue
# Image number :  15  True Label : blue  Predicted Label :  red
# Image number :  16  True Label : blue  Predicted Label :  red
# Image number :  17  True Label : blue  Predicted Label :  blue
# Image number :  18  True Label : blue  Predicted Label :  red
# Image number :  19  True Label : blue  Predicted Label :  blue
# Image number :  20  True Label : blue  Predicted Label :  red
# Image number :  21  True Label : blue  Predicted Label :  blue
# Image number :  22  True Label : blue  Predicted Label :  red
# Image number :  23  True Label : blue  Predicted Label :  red
# Image number :  24  True Label : blue  Predicted Label :  red
# Image number :  25  True Label : blue  Predicted Label :  red
# Image number :  26  True Label : blue  Predicted Label :  blue
# Image number :  27  True Label : blue  Predicted Label :  red
# Image number :  28  True Label : blue  Predicted Label :  blue
# Image number :  29  True Label : blue  Predicted Label :  red
# Image number :  30  True Label : blue  Predicted Label :  blue
# Image number :  31  True Label : blue  Predicted Label :  blue
# Image number :  32  True Label : blue  Predicted Label :  blue
# Image number :  33  True Label : blue  Predicted Label :  blue
# Image number :  34  True Label : blue  Predicted Label :  blue
# Image number :  35  True Label : blue  Predicted Label :  blue
# Image number :  36  True Label : blue  Predicted Label :  red
# Image number :  37  True Label : blue  Predicted Label :  blue
# Image number :  111  True Label : red  Predicted Label :  red
# Image number :  112  True Label : red  Predicted Label :  red
# Image number :  113  True Label : red  Predicted Label :  red
# Image number :  114  True Label : red  Predicted Label :  red
# Image number :  115  True Label : red  Predicted Label :  red
# Image number :  116  True Label : red  Predicted Label :  red
# Image number :  117  True Label : red  Predicted Label :  red
# Image number :  118  True Label : red  Predicted Label :  red
# Image number :  119  True Label : red  Predicted Label :  red
# Image number :  120  True Label : red  Predicted Label :  red
# Image number :  121  True Label : red  Predicted Label :  blue

# %% [markdown]
# # Question 7

# %%
def sample_spherical(npoints, ndim=1):
    x = np.random.rand(ndim, npoints)
    y = np.cos(2 * np.pi * x)
    noise = np.random.normal(0,1,npoints)
    y = y + noise
    return x, y

x, y = sample_spherical(100)

plt.plot(x,y, 'bo')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
# from mlxtend.evaluate import bias_variance_decomp

def fit_line(x, y, degree):
    z = np.polyfit(x, y, degree)                
    p = np.poly1d(z)                              

    xp = np.linspace(0, 1)       

    plt.scatter(x,y, color='black')
    plt.plot(xp, p(xp), '-', color='blue')
    plt.show()
    print('Mean Square Error for degree: ', degree, ' Is: ', mean_squared_error(y, p(x)))
#     mse, bias, var = bias_variance_decomp(model, X_train, y_train, X_test, y_test, loss='mse', num_rounds=200, random_seed=1)

x_ = x.reshape(-1)
y_ = y.reshape(-1)
degrees = [1, 4, 8, 12, 15, 20]
for i in degrees:
    fit_line(x_, y_, i)
# Out:
# Mean Square Error for degree:  1  Is:  1.0397695909120643
# Mean Square Error for degree:  4  Is:  0.7248998584369957
# Mean Square Error for degree:  8  Is:  0.7153361101764822
# Mean Square Error for degree:  12  Is:  0.6671939670532661
# Mean Square Error for degree:  15  Is:  0.6215472611487245
# <ipython-input-275-02180eb92eb5>:20: RankWarning: Polyfit may be poorly conditioned
#   fit_line(x_, y_, i)
# Mean Square Error for degree:  20  Is:  0.6082627920320054

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

p_reg= Pipeline([
            ("poly_features", PolynomialFeatures(degree=20, include_bias=False)),
            ("lin_reg", LinearRegression()),
        ])
p_reg.fit(x, y)
y_pred = p_reg.predict(x)

plt.scatter(x,y, color='black')
plt.plot(x, y_pred, '-', color='blue')
plt.show()
    
mean_squared_error(y, y_pred)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-282-ead733ceeccd> in <module>
#       6             ("lin_reg", LinearRegression()),
#       7         ])
# ----> 8 p_reg.fit(x, y)
#       9 y_pred = p_reg.predict(x)
#      10
#
# ~\anaconda3\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     328         """
#     329         fit_params_steps = self._check_fit_params(**fit_params)
# --> 330         Xt = self._fit(X, y, **fit_params_steps)
#     331         with _print_elapsed_time('Pipeline',
#     332                                  self._log_message(len(self.steps) - 1)):
#
# ~\anaconda3\lib\site-packages\sklearn\pipeline.py in _fit(self, X, y, **fit_params_steps)
#     290                 cloned_transformer = clone(transformer)
#     291             # Fit or load from cache the current transformer
# --> 292             X, fitted_transformer = fit_transform_one_cached(
#     293                 cloned_transformer, X, y, None,
#     294                 message_clsname='Pipeline',
#
# ~\anaconda3\lib\site-packages\joblib\memory.py in __call__(self, *args, **kwargs)
#     350
#     351     def __call__(self, *args, **kwargs):
# --> 352         return self.func(*args, **kwargs)
#     353
#     354     def call_and_shelve(self, *args, **kwargs):
#
# ~\anaconda3\lib\site-packages\sklearn\pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     738     with _print_elapsed_time(message_clsname, message):
#     739         if hasattr(transformer, 'fit_transform'):
# --> 740             res = transformer.fit_transform(X, y, **fit_params)
#     741         else:
#     742             res = transformer.fit(X, y, **fit_params).transform(X)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     691         else:
#     692             # fit method of arity 2 (supervised transformation)
# --> 693             return self.fit(X, y, **fit_params).transform(X)
#     694
#     695
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y)
#    1516                                           self.include_bias)
#    1517         self.n_input_features_ = n_features
# -> 1518         self.n_output_features_ = sum(1 for _ in combinations)
#    1519         return self
#    1520
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in <genexpr>(.0)
#    1516                                           self.include_bias)
#    1517         self.n_input_features_ = n_features
# -> 1518         self.n_output_features_ = sum(1 for _ in combinations)
#    1519         return self
#    1520
#
# KeyboardInterrupt:
